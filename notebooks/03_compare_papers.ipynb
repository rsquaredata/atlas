# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

sys.path.append(
    str(project_root / "src")
)

# %%
import networkx as nx

from atlas.comparison import (
    common_nodes,
    fuzzy_common_nodes,
    semantic_common_nodes
)

from atlas.embeddings import (
    EmbeddingModel
)

# %%
g_autokaggle = nx.read_graphml(
    "../data/graphs/autokaggle.graphml"
)

g_aide = nx.read_graphml(
    "../data/graphs/aide.graphml"
)

g_data_interpreter = nx.read_graphml(
    "../data/graphs/datainterpreter.graphml"
)

g_ai_scientist = nx.read_graphml(
    "../data/graphs/ai_scientist.graphml"
)

g_swe_agent = nx.read_graphml(
    "../data/graphs/swe_agent.graphml"
)

g_openhands = nx.read_graphml(
    "../data/graphs/openhands.graphml"
)

# %%
print("AutoKaggle:", len(g_autokaggle.nodes()))
print("AIDE:", len(g_aide.nodes()))
print("Data Interpreter:", len(g_data_interpreter.nodes()))
# Out:
# AutoKaggle: 10
# AIDE: 9
# Data Interpreter: 6

# %%
common = common_nodes(
    g_autokaggle,
    g_aide
)

print(common)
# Out:
# set()

# %%
matches = fuzzy_common_nodes(
    g_autokaggle,
    g_aide
)

for match in matches:
    print(match)
# Out:
# ('AutoKaggle', 'Kaggle evaluations', 71.42857142857143)
# ('Kaggle Competitions', 'Kaggle evaluations', 70.27027027027026)

# %%
semantic_matches = semantic_common_nodes(
    g_autokaggle,
    g_aide,
)

for match in semantic_matches:
    print(match)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ('Kaggle Competitions', 'Kaggle evaluations', np.float32(0.6389116))
# ('Code Execution', 'code optimization', np.float32(0.5997845))

# %%
semantic_matches = semantic_common_nodes(
    g_autokaggle,
    g_data_interpreter
)

for match in semantic_matches:
    print(match)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ('Multi-Agent System', 'LLM-based agent', np.float32(0.57442915))

# %%
semantic_matches = semantic_common_nodes(
    g_aide,
    g_data_interpreter
)

for match in semantic_matches:
    print(match)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
semantic_matches = semantic_common_nodes(
    g_aide,
    g_ai_scientist
)

for match in semantic_matches:
    print(match)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ('large language models', 'frontier large language models', np.float32(0.84802437))
# ('large language models', 'transformer-based language modeling', np.float32(0.66848755))

# %%
semantic_matches = semantic_common_nodes(
    g_autokaggle,
    g_ai_scientist
)

for match in semantic_matches:
    print(match)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ('Multi-Agent System', 'agent workflow', np.float32(0.65281594))

# %%
semantic_common_nodes(
    g_swe_agent,
    g_aide
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [('Language Model Agent', 'large language models', np.float32(0.6817878)),
#  ('SWE-bench', 'METRs RE-Bench', np.float32(0.56899863)),
#  ('SWE-bench', 'OpenAI MLE-Bench', np.float32(0.56793034))]

# %%
semantic_common_nodes(
    g_swe_agent,
    g_autokaggle
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [('Agent-Computer Interface', 'Multi-Agent System', np.float32(0.7247398))]

# %%
print(
    model.similarity(
        "machine learning engineering agent",
        "LLM-based agent"
    )
)
# Out:
# 0.5299716

# %%
print(
    model.similarity(
        "large language models",
        "LLM-based agent"
    )
)
# Out:
# 0.2452072

# %%
print(
    model.similarity(
        "Multi-Agent System",
        "machine learning engineering agent"
    )
)
# Out:
# 0.42150354

# %%
print(
    model.similarity(
        "Multi-Agent System",
        "AI-Driven Exploration"
    )
)
# Out:
# 0.30168355

# %%
semantic_common_nodes(
    g_openhands,
    g_autokaggle
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [('Code Execution', 'Code Execution', np.float32(1.0000002)),
#  ('Multi-Agent System', 'Multi-Agent System', np.float32(1.0000001)),
#  ('AI agents', 'Multi-Agent System', np.float32(0.6514053))]

# %%
semantic_common_nodes(
    g_openhands,
    g_aide
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [('AI agents', 'machine learning engineering agent', np.float32(0.6449552)),
#  ('Code Execution', 'code optimization', np.float32(0.5997845)),
#  ('SWE-BENCH', 'METRs RE-Bench', np.float32(0.56899863)),
#  ('SWE-BENCH', 'OpenAI MLE-Bench', np.float32(0.56793034)),
#  ('AI agents', 'AI-Driven Exploration', np.float32(0.55550617))]
